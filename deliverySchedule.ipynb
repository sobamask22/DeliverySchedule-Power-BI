# %% [markdown]
# # Import Libraries

# %%
# Step 1: Import libraries
import pandas as pd
import os

# %%
# Step 2: Define the file path and type
# 🔧 Customize this path to point to your local file
file_path = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.1 Raw Data\deliveryScheduleCSV.csv" 

# Instruct python to display all columns of the dataframe for inspection
pd.set_option('display.max_columns', None)

# Load and display dataframe
df = pd.read_csv(file_path)
df.head()
# Out:
#                                      PRODUCT  QUANTITY     UNIT  \
# 0                 Pizza Boxes X100 (12 Inch)      24.0  Pallets
# 1              Ready Mix Fireaway Flour 25KG      21.0  Pallets
# 2             Semolina Streching Flour- 25KG       3.0  Pallets
# 3              Ready Mix Fireaway Flour 25KG      24.0  Pallets
# 4  Franks- Red Hot Buffalo Sauce- 3.78/3.9KG       1.0  Pallets
#
#   CATEGORY OF PRODUCT               SUPPLIER CONTAINER NO  \
# 0           Packaging               ANKUTSAN  FFAU3153198
# 1             Ambient  MOLINI PIZZUTI S.R.L.  CMAU6192040
# 2             Ambient  MOLINI PIZZUTI S.R.L.  CMAU6192040
# 3             Ambient  MOLINI PIZZUTI S.R.L.  SEGU5061754
# 4        Dips & Sauce                RH AMAR          NaN
#
#   ETA - WAREHOUSE DELIVERY BOOKING/ORDER NO ETA - DATE OF ENTRY   \
# 0                26/3/2025       2156692420            26/3/2025
# 1                26/3/2025      TLPL2549983            26/3/2025
# ...

# %% [markdown]
# # Create Unique Product Names Lookup Sheet for PBI

# %%
# Create a new DataFrame with unique Product Names
unique_product_df = pd.DataFrame(df["PRODUCT"].unique(), columns=["PRODUCT"])

# Preview the result
unique_product_df
# Out:
#                                                PRODUCT
# 0                           Pizza Boxes X100 (12 Inch)
# 1                        Ready Mix Fireaway Flour 25KG
# 2                       Semolina Streching Flour- 25KG
# 3            Franks- Red Hot Buffalo Sauce- 3.78/3.9KG
# 4                                   Mozzarella 2KG X 6
# ..                                                 ...
# 148  Fireaway Pizza Special Edition T-Shirt (Orange...
# 149                 Gastro 1/4 Container(Metal)- 150MM
# 150      Heat Resistant Spoonula 10 Inch (Pasta Spoon)
# 151                        Gluten Free Pizza Protecter
# 152                                                NaN
#
# [153 rows x 1 columns]

# %%
# 📁 Define your target directory and filename
target_dir = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files"  # 🔧 Change this to your desired path
file_name_1 = "unique_product sheet.csv"
full_path_1 = os.path.join(target_dir, file_name_1)


# 📝 Step 3: Save the DataFrame as a CSV
unique_product_df.to_csv(full_path_1, index=True)

print(f"✅ File saved successfully at: {full_path_1}")
# Out:
# ✅ File saved successfully at: C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files\unique_product sheet.csv

# %% [markdown]
# # Create Unique Unit Types Lookup Sheet for PBI

# %%
# Create a new DataFrame with unique Product Names
unique_unit_types_df = pd.DataFrame(df["UNIT"].unique(), columns=["UNIT"])

# Preview the result
unique_unit_types_df
# Out:
#          UNIT
# 0     Pallets
# 1   Kilograms
# 2       Cases
# 3       Boxes
# 4       Packs
# 5       Units
# 6      Litres
# 7  Individual
# 8         NaN

# %%
# 📁 Define your target directory and filename
target_dir = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files"  # 🔧 Change this to your desired path
file_name_2 = "unique_unit_types sheet.csv"
full_path_2 = os.path.join(target_dir, file_name_2)


# 📝 Step 3: Save the DataFrame as a CSV
unique_unit_types_df.to_csv(full_path_2, index=True)

print(f"✅ File saved successfully at: {full_path_2}")
# Out:
# ✅ File saved successfully at: C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files\unique_unit_types sheet.csv

# %% [markdown]
# # Create Unique Category of Product Lookup Sheet for PBI

# %%
# Create a new DataFrame with unique Product Names
unique_category_of_product_df = pd.DataFrame(df["CATEGORY OF PRODUCT"].unique(), columns=["CATEGORY OF PRODUCT"])

# Preview the result
unique_category_of_product_df
# Out:
#    CATEGORY OF PRODUCT
# 0            Packaging
# 1              Ambient
# 2         Dips & Sauce
# 3              Chilled
# 4               Frozen
# 5           Drinks Can
# 6        Drinks Bottle
# 7            Equipment
# 8        Miscellaneous
# 9              Uniform
# 10                 NaN

# %%
# 📁 Define your target directory and filename
target_dir = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files"  # 🔧 Change this to your desired path
file_name_3 = "unique_category_of_product sheet.csv"
full_path_3 = os.path.join(target_dir, file_name_3)


# 📝 Step 3: Save the DataFrame as a CSV
unique_category_of_product_df.to_csv(full_path_3, index=True)

print(f"✅ File saved successfully at: {full_path_3}")
# Out:
# ✅ File saved successfully at: C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files\unique_category_of_product sheet.csv

# %% [markdown]
# # Create Unique Supplier Lookup Sheet for PBI

# %%
# Create a new DataFrame with unique Product Names
unique_supplier_df = pd.DataFrame(df["SUPPLIER"].unique(), columns=["SUPPLIER"])

# Preview the result
unique_supplier_df
# Out:
#                     SUPPLIER
# 0                   ANKUTSAN
# 1      MOLINI PIZZUTI S.R.L.
# 2                    RH AMAR
# 3              LEPRINO FOODS
# 4                MAMMA FIORE
# 5                 MPO GLOBAL
# 6                    UPFIELD
# 7              MINSTER FOODS
# 8   ITALIAN BEVERAGE COMPANY
# 9           COCA COLA (CCEP)
# 10             MARTIN MATTEW
# 11                TREND PACK
# 12                WEST BAKES
# 13                       CFW
# 14                RIVA FOODS
# 15                 STERILTOM
# 16                   H SMITH
# 17             CRUCIAL FOODS
# 18               FAYRE FIELD
# 19        UROPA - EQUIPMENT
# 20                  RED BULL
# 21                 GRANTERRE
# 22           LONDON LIDS LTD
# 23                  UNILEVER
# 24            KTC FOOD GROUP
# 25             B1 EUROPE LTD
# 26                  BADITECH
# 27            HOLLAND BAZZAR
# 28             JE MORTEN LTD
# 29            CREATIVE FOODS
# 30          THE SALT COMPANY
# ...

# %%
# 📁 Define your target directory and filename
target_dir = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files"  # 🔧 Change this to your desired path
file_name_4 = "unique_supplier sheet.csv"
full_path_4 = os.path.join(target_dir, file_name_4)


# 📝 Step 3: Save the DataFrame as a CSV
unique_supplier_df.to_csv(full_path_4, index=True)

print(f"✅ File saved successfully at: {full_path_4}")
# Out:
# ✅ File saved successfully at: C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files\unique_supplier sheet.csv

# %% [markdown]
# # Create Unique Country of Shipping Lookup Sheet for PBI

# %%
# Create a new DataFrame with unique Product Names
unique_country_of_shipping_df = pd.DataFrame(df["COUNTRY OF SHIPPING"].unique(), columns=["COUNTRY OF SHIPPING"])

# Preview the result
unique_country_of_shipping_df
# Out:
#   COUNTRY OF SHIPPING
# 0              Turkey
# 1              Italy
# 2      United Kingdom
# 3             Belgium
# 4               Egypt
# 5              TURKEY
# 6                 NaN

# %%
# 📁 Define your target directory and filename
target_dir = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files"  # 🔧 Change this to your desired path
file_name_5 = "unique_country_of_shipping sheet.csv"
full_path_5 = os.path.join(target_dir, file_name_5)


# 📝 Step 3: Save the DataFrame as a CSV
unique_country_of_shipping_df.to_csv(full_path_5, index=True)

print(f"✅ File saved successfully at: {full_path_5}")
# Out:
# ✅ File saved successfully at: C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files\unique_country_of_shipping sheet.csv

# %% [markdown]
# # Create Unique Order Status Lookup Sheet for PBI

# %%
# Create a new DataFrame with unique Product Names
unique_order_status_df = pd.DataFrame(df["ORDER LATE?"].unique(), columns=["ORDER LATE?"])

# Preview the result
unique_order_status_df
# Out:
#   ORDER LATE?
# 0     On Time
# 1        Late
# 2         NaN

# %%
# 📁 Define your target directory and filename
target_dir = r"C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files"  # 🔧 Change this to your desired path
file_name_5 = "unique_country_of_shipping sheet.csv"
full_path_5 = os.path.join(target_dir, file_name_5)


# 📝 Step 3: Save the DataFrame as a CSV
unique_country_of_shipping_df.to_csv(full_path_5, index=True)

print(f"✅ File saved successfully at: {full_path_5}")
# Out:
# ✅ File saved successfully at: C:\Users\emman\OneDrive\Desktop\PowerBi Practice Folders\Fireaway Delivery Schedule PBI\0.2 CSV Files\unique_country_of_shipping sheet.csv
